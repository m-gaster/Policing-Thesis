# %%
pip install textdistance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import textdistance

# %%
df = pd.read_csv(r"Traffic_Violations.csv")
# Out:
# C:\Users\mikha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,20,21,22,23,24,25,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## First Matching Array
#
# Only matches if strings are exact match (with '/', '\\' swapped, etc.)

# %%
"""
THIS IS THE PERCENT OF ENTRIES WITH MISSING LONG/LAT
"""
39.031643, -77.063164
38.973480, -76.969780

print('% missing LATITUDE ==', len([x for x in df['Latitude'] if not 38.973480<=x<=39.031643])/len(df))
print('% missing LONGITUDE ==', len([x for x in df['Longitude'] if not -77.063164 <=x<=-76.969780])/len(df))
# Out:
# % missing LATITUDE == 0.772657959569774
# % missing LONGITUDE == 0.7033949296078215

# %%
df['Latitude'].describe()
# Out:
# count    1.670285e+06
# mean     3.629556e+01
# std      1.005739e+01
# min      0.000000e+00
# 25%      3.901514e+01
# 50%      3.906330e+01
# 75%      3.912785e+01
# max      4.154316e+01
# Name: Latitude, dtype: float64

# %%
df['Longitude']
# Out:
# 0         -77.151645
# 1         -77.051137
# 2           0.000000
# 3         -77.096600
# 4           0.000000
#              ...
# 1670280   -76.988186
# 1670281   -76.988186
# 1670282   -76.988186
# 1670283   -77.082185
# 1670284   -76.991107
# Name: Longitude, Length: 1670285, dtype: float64

# %%
df['Location'].head(60)
# Out:
# 0             RIVER RD/ROYAL DOMINION DR
# 1              ENNALLS AVE @ GEORGIA AVE
# 2                   SHADY GROVE @ TUPELO
# 3                 355 AT JONES BRIDGE RD
# 4           GERMANTOWN AT SHAKESPEARE RD
# 5                    GEORGIA/ BALLARD ST
# 6                 RIVER RD/BRAEBURN PKWY
# 7     SOUTHBOUND 29 AND GREENCASTLE ROAD
# 8                      355/ GROSVENOR PL
# 9              TECH ROAD/INDUSTRIAL PKWY
# 10                LAYHILL RD @ BRIGGS RD
# 11              GEORGIA AVENUE / ICC 200
# 12          UNIVERSITY BLVD W/DENNIS AVE
# 13             SAPLING RIDGE RD / RT 650
# 14                 14000 S/B GEORGIA AVE
# 15             RANDOLPH RD @ CHAPMAN AVE
# 16         DARNESTOWN RD @ PHYSICIANS LN
# 17             RANDOLPH RD @ CHAPMAN AVE
# 18             NB RT 650 AT TREE LAWN DR
# 19                  W/B MD 124 @ BANK ST
# 20                 COLESVILLE/UNIVERSITY
# 21                     S. SUMMITT/HUTTON
# 22                      1700 ARCOLA AVE.
# ...

# %%
"""
Replacing '/' with '@' if it's used the same way
"""

def in_middle_of_word(letter, word): #returns true if all instances of letter in word are toward the middle
    if 2<=len(word)<=4:
        return False
    else:
        
    
    MIDDLE_LEN = round(len(word) / 2)
    
    
    
     

for i,x in enumerate(df['Location']):
    for j, word in enumerate(x.split()):
        if '/' in word and in_middle_of_word('/', word)==True:
            #if '/' is near the middle of the word
            for k, letter in enumerate(word):
                if
