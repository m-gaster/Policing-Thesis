# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # New Method

# %%
# Out:
# <style>.container { width:95% !important; }</style>

# %%
df = pd.read_csv(r"Police Stops vs Accidents - width=.005.csv")

# %%
df.head()
# Out:
#     long   lat  Total Stops  Total Citations  Total Accidents  Total Injuries  \
# 0 -77.45 39.42           80               36                0               0
# 1 -77.44 39.40           33               14                5               0
# 2 -77.44 39.20           35               12                5               4
# 3 -77.43 39.22          429                5                0               0
# 4 -77.43 39.42           40               13                2               0
#
#    Total Fatalities                           geometry  Stops per Accident  \
# 0                 0             POINT (-77.455 39.425)                0.00
# 1                 0  POINT (-77.44499999999999 39.395)                6.60
# 2                 0             POINT (-77.435 39.205)                7.00
# 3                 0  POINT (-77.43000000000001 39.215)                0.00
# 4                 0  POINT (-77.43000000000001 39.425)               20.00
#
# ...

# %%
df['Normalized Stops per Accident'].hist(log=True)
# Out:
# <AxesSubplot:>
