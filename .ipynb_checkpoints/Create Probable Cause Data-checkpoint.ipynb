# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\mikha\OneDrive\Desktop\Dropbox\MIKHAEL NEW\mikhael school\Year 5\Econ 490\Datasets\Traffic_Violations.csv")
# Out:
# C:\Users\mikha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,20,21,22,23,24,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.drop(columns=['Description','Location'])

# %%
df.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  2f0bb173-ad15-4cd7-98d4-3bb5bb570516   09/01/2019     22:51:00    MCP
# 1  2f0bb173-ad15-4cd7-98d4-3bb5bb570516   09/01/2019     22:51:00    MCP
# 2  ca336e6f-09a3-4885-8107-688677eb96da   09/01/2019     22:46:00    MCP
# 3  9440b41f-6917-4092-a2e4-97426d5dc4de   09/01/2019     22:44:00    MCP
# 4  9440b41f-6917-4092-a2e4-97426d5dc4de   09/01/2019     22:44:00    MCP
#
#                   SubAgency   Latitude  Longitude Accident Belts  \
# 0     4th District, Wheaton  39.064348 -77.056282       No   Yes
# 1     4th District, Wheaton  39.064348 -77.056282       No   Yes
# 2  5th District, Germantown  39.179913 -77.268270       No    No
# 3   1st District, Rockville  39.075012 -77.136492       No    No
# 4   1st District, Rockville  39.075012 -77.136492       No    No
#
#   Personal Injury  ...        Charge                 Article  \
# 0              No  ...     13-411(d)  Transportation Article
# ...

# %%
df.columns
# Out:
# Index(['SeqID', 'Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency',
#        'Latitude', 'Longitude', 'Accident', 'Belts', 'Personal Injury',
#        'Property Damage', 'Fatal', 'Commercial License', 'HAZMAT',
#        'Commercial Vehicle', 'Alcohol', 'Work Zone', 'Search Conducted',
#        'Search Disposition', 'Search Outcome', 'Search Reason',
#        'Search Reason For Stop', 'Search Type', 'Search Arrest Reason',
#        'State', 'VehicleType', 'Year', 'Make', 'Model', 'Color',
#        'Violation Type', 'Charge', 'Article', 'Contributed To Accident',
#        'Race', 'Gender', 'Driver City', 'Driver State', 'DL State',
#        'Arrest Type', 'Geolocation'],
#       dtype='object')

# %%
df = df[ df['Search Conducted'] == "Yes" ]

df['Search Conducted'].head()
# Out:
# 12     Yes
# 224    Yes
# 236    Yes
# 237    Yes
# 238    Yes
# Name: Search Conducted, dtype: object

# %%
df['Search Outcome'].hist()

# %%
df[df['Search Reason'] == 'Probable Cause']['Search Outcome'].hist()
