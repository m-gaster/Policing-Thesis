# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"Traffic_Violations.csv")
# Out:
# C:\Users\mikha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,20,21,22,23,24,25,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.insert(0, 'Unique Stop ID', [x[0]+x[1]+x[2] for x in zip(df['SeqID'], df['Date Of Stop'], df['Time Of Stop'])])
del df['SeqID']
del df['Geolocation']

# %%
citation_counting_dict = {ID: 0 for ID in df['Unique Stop ID']}

for i, ID in enumerate(df['Unique Stop ID']):
    if df['Violation Type'].iloc[i] == 'Citation':
        citation_counting_dict[ID] += 1

# %%
df.insert(3, 'Number of Citations', [citation_counting_dict[ID] for ID in df['Unique Stop ID']])

# %%
df = df.sort_values(by=['Date Of Stop', 'Time Of Stop', 'Unique Stop ID'])

# %%
# pd.set_option('display.max_colwidth', None)
# df.head(15)
# Out:
#                                                 Unique Stop ID Date Of Stop  \
# 466662  845c2732-d70b-42ef-bde8-603f9563aa2801/01/201200:43:00   01/01/2012
# 84087   b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb01/01/201200:52:00   01/01/2012
# 88029   b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb01/01/201200:52:00   01/01/2012
# 88155   b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb01/01/201200:52:00   01/01/2012
# 89989   b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb01/01/201200:52:00   01/01/2012
# 91500   b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb01/01/201200:52:00   01/01/2012
# 93438   b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb01/01/201200:52:00   01/01/2012
# 94368   b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb01/01/201200:52:00   01/01/2012
# 228116  2e5265a0-df21-4634-b1a7-9bc180ef77e501/01/201201:30:00   01/01/2012
# 231189  2e5265a0-df21-4634-b1a7-9bc180ef77e501/01/201201:30:00   01/01/2012
# 232890  2e5265a0-df21-4634-b1a7-9bc180ef77e501/01/201201:30:00   01/01/2012
# 234335  2e5265a0-df21-4634-b1a7-9bc180ef77e501/01/201201:30:00   01/01/2012
# 235292  2e5265a0-df21-4634-b1a7-9bc180ef77e501/01/201201:30:00   01/01/2012
# 235776  2e5265a0-df21-4634-b1a7-9bc180ef77e501/01/201201:30:00   01/01/2012
# 236318  2e5265a0-df21-4634-b1a7-9bc180ef77e501/01/201201:30:00   01/01/2012
#
#        Time Of Stop  Number of Citations Agency  \
# 466662     00:43:00                    0    MCP
# 84087      00:52:00                    7    MCP
# 88029      00:52:00                    7    MCP
# 88155      00:52:00                    7    MCP
# 89989      00:52:00                    7    MCP
# 91500      00:52:00                    7    MCP
# 93438      00:52:00                    7    MCP
# 94368      00:52:00                    7    MCP
# 228116     01:30:00                   11    MCP
# 231189     01:30:00                   11    MCP
# 232890     01:30:00                   11    MCP
# 234335     01:30:00                   11    MCP
# 235292     01:30:00                   11    MCP
# 235776     01:30:00                   11    MCP
# 236318     01:30:00                   11    MCP
#
#                                   SubAgency  \
# 466662  Headquarters and Special Operations
# 84087           3rd District, Silver Spring
# 88029           3rd District, Silver Spring
# 88155           3rd District, Silver Spring
# 89989           3rd District, Silver Spring
# 91500           3rd District, Silver Spring
# 93438           3rd District, Silver Spring
# 94368           3rd District, Silver Spring
# 228116                4th District, Wheaton
# 231189                4th District, Wheaton
# 232890                4th District, Wheaton
# 234335                4th District, Wheaton
# 235292                4th District, Wheaton
# 235776                4th District, Wheaton
# 236318                4th District, Wheaton
#
#                                                                                               Description  \
# 466662                                                              LEFT TURN FROM IMPROPER ROAD POSITION
# 84087                                                                   DRIVING WHILE IMPAIRED BY ALCOHOL
# 88029                   DRIVER CONSUMING ALCOHOLIC BEVERAGE IN PASSENGER AREA OF MOTOR VEHICLE ON HIGHWAY
# 88155                                                                 KNOWINGLY DRIVING UNINSURED VEHICLE
# 89989           FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND
# 91500   PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE
# 93438           PERSON DRIVING MOTOR VEHICLE WHILE LICENSE SUSPENDED UNDER 17-106, 26-204, 26-206, 27-103
# 94368                                                DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF ALCOHOL
# 228116                                   FAILURE TO STOP AFTER ACCIDENT INVOLVING DAMAGE TO ATTENDED VEH.
# 231189    PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON REVOKED LICENSE AND PRIVILEGE
# 232890  PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE
# 234335                                                                         FOLLOWING VEH. TOO CLOSELY
# 235292          FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND
# 235776           FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDER REASONABLE ASSISTANCE TO INJURED PERSON
# 236318                                           FAILURE TO CONTROL VEH. SPEED ON HWY. TO AVOID COLLISION
#
#                                  Location  Latitude  Longitude  ...  \
# 466662                  FENTON AT CAMERON  39.00102 -77.033344  ...
# 84087   PINEY BRANCH ROAD @ ARLISS STREET   0.00000   0.000000  ...
# 88029   PINEY BRANCH ROAD @ ARLISS STREET   0.00000   0.000000  ...
# 88155   PINEY BRANCH ROAD @ ARLISS STREET   0.00000   0.000000  ...
# 89989   PINEY BRANCH ROAD @ ARLISS STREET   0.00000   0.000000  ...
# 91500   PINEY BRANCH ROAD @ ARLISS STREET   0.00000   0.000000  ...
# 93438   PINEY BRANCH ROAD @ ARLISS STREET   0.00000   0.000000  ...
# 94368   PINEY BRANCH ROAD @ ARLISS STREET   0.00000   0.000000  ...
# 228116   GEORGIA AVE (SB) / SHOREFIELD RD   0.00000   0.000000  ...
# 231189   GEORGIA AVE (SB) / SHOREFIELD RD   0.00000   0.000000  ...
# 232890   GEORGIA AVE (SB) / SHOREFIELD RD   0.00000   0.000000  ...
# 234335   GEORGIA AVE (SB) / SHOREFIELD RD   0.00000   0.000000  ...
# 235292   GEORGIA AVE (SB) / SHOREFIELD RD   0.00000   0.000000  ...
# 235776   GEORGIA AVE (SB) / SHOREFIELD RD   0.00000   0.000000  ...
# 236318   GEORGIA AVE (SB) / SHOREFIELD RD   0.00000   0.000000  ...
#
#        Violation Type      Charge                 Article  \
# 466662        Warning   21-601(b)  Transportation Article
# 84087        Citation  21-902(b1)  Transportation Article
# 88029        Citation   21-903(c)  Transportation Article
# 88155        Citation      17-107  Transportation Article
# 89989        Citation   16-112(c)  Transportation Article
# 91500        Citation   16-303(c)  Transportation Article
# 93438        Citation   16-303(h)  Transportation Article
# 94368        Citation  21-902(a1)  Transportation Article
# 228116       Citation   20-103(a)  Transportation Article
# 231189       Citation   16-303(d)  Transportation Article
# 232890       Citation   16-303(c)  Transportation Article
# 234335       Citation   21-310(a)  Transportation Article
# 235292       Citation   16-112(c)  Transportation Article
# 235776       Citation   20-104(a)  Transportation Article
# 236318       Citation   21-801(b)  Transportation Article
#
#        Contributed To Accident      Race Gender    Driver City Driver State  \
# 466662                   False     WHITE      M        HERNDON           VA
# 84087                    False  HISPANIC      F  SILVER SPRING           MD
# 88029                    False  HISPANIC      F  SILVER SPRING           MD
# 88155                    False  HISPANIC      F  SILVER SPRING           MD
# 89989                    False  HISPANIC      F  SILVER SPRING           MD
# 91500                    False  HISPANIC      F  SILVER SPRING           MD
# 93438                    False  HISPANIC      F  SILVER SPRING           MD
# 94368                    False  HISPANIC      F  SILVER SPRING           MD
# 228116                   False     WHITE      M    TAKOMA PARK           MD
# 231189                   False     WHITE      M    TAKOMA PARK           MD
# 232890                   False     WHITE      M    TAKOMA PARK           MD
# 234335                    True     WHITE      M    TAKOMA PARK           MD
# 235292                   False     WHITE      M    TAKOMA PARK           MD
# 235776                   False     WHITE      M    TAKOMA PARK           MD
# 236318                    True     WHITE      M    TAKOMA PARK           MD
#
#        DL State        Arrest Type
# 466662       VA  A - Marked Patrol
# 84087        MD  A - Marked Patrol
# 88029        MD  A - Marked Patrol
# 88155        MD  A - Marked Patrol
# 89989        MD  A - Marked Patrol
# 91500        MD  A - Marked Patrol
# 93438        MD  A - Marked Patrol
# 94368        MD  A - Marked Patrol
# 228116       MD  A - Marked Patrol
# 231189       MD  A - Marked Patrol
# 232890       MD  A - Marked Patrol
# 234335       MD  A - Marked Patrol
# 235292       MD  A - Marked Patrol
# 235776       MD  A - Marked Patrol
# 236318       MD  A - Marked Patrol
#
# [15 rows x 43 columns]

# %%
df.to_csv("Traffic_Violations", index=False)
