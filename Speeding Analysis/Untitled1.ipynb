# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\mikha\Dropbox\mikhael_misc\Projects\Policing Thesis\Speeding Analysis\Police Stops vs Accidents - width=0.005 - 2021-03-17.csv")

# %%
df.head()
# Out:
#      long     lat  Total Stops  Total Citations  Total Accidents  \
# 0 -77.455  39.425           80               36                0
# 1 -77.445  39.395           33               14                5
# 2 -77.435  39.205           35               12                5
# 3 -77.430  39.215          429                5                0
# 4 -77.430  39.425           40               13                2
#
#    Total Injuries  Total Fatalities                           geometry  \
# 0               0                 0             POINT (-77.455 39.425)
# 1               0                 0  POINT (-77.44499999999999 39.395)
# 2               4                 0             POINT (-77.435 39.205)
# 3               0                 0  POINT (-77.43000000000001 39.215)
# 4               0                 0  POINT (-77.43000000000001 39.425)
#
#    Stops per Accident  Accidents per Stop  ...  Normalized Total Accidents  \
# ...

# %%
df['Total Stops'].sum()
# Out:
# 1535575

# %%
df['Total Stops'].sum()
# Out:
# 1535575

# %%
df2 = pd.read_excel(r"C:\Users\mikha\Dropbox\mikhael_misc\Projects\Policing Thesis\Speeding Analysis\Data From Dad - Apr 1 2021.xlsx")

# %%
df['Total Accidents'].sum()
# Out:
# 44545

# %%
df2.head()
# Out:
#           Date Of Stop Time Of Stop Agency   Latitude  Longitude Accident  \
# 0  2015-01-01 00:00:00     22:32:00    MCP  38.961283 -77.133463       No
# 1  2015-01-01 00:00:00     22:11:00    MCP  38.961388 -77.133508       No
# 2  2015-01-01 00:00:00     22:01:00    MCP  38.962597 -77.134805       No
# 3  2015-01-01 00:00:00     18:30:00    MCP  38.978688 -77.207180       No
# 4  2015-01-01 00:00:00     16:31:00    MCP  38.980472 -77.088520       No
#
#   Personal Injury Property Damage Fatal Search Conducted State Violation Type  \
# 0              No              No    No               No    MD        Warning
# 1              No              No    No               No    VA        Warning
# 2              No              No    No               No    DC        Warning
# 3              No              No    No               No    MD        Warning
# 4              No              No    No               No    MD        Warning
#
#     Race Gender
# 0  BLACK      F
# 1  OTHER      F
# ...

# %%
np.where(df2['Accident']=='Yes', 1, 0).sum()
# Out:
# 9526

# %%
len(df2)
# Out:
# 603338
